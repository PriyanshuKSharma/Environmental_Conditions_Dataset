# %% [markdown]
# <a href="https://colab.research.google.com/github/Neha-Gaikwad/Environmental_Conditions_Dataset/blob/main/matplot(3_8_24)_pynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x =[1,2,3,4]
y = [2,4,6,8]

# %%
x,y
# Out:
# ([1, 2, 3, 4], [2, 4, 6, 8])

# %%
plt.plot(x,y)

# %%
plt.plot(x,y , ls="dotted")

# %%
plt.plot(x,y , ls="-.")

# %%
plt.plot(x,y , ls="-.")

# %%
plt.plot(x,y , ls=":")

# %%
plt.plot(x,y , ls="--")

# %%
#to highlights the points
plt.plot(x,y , ls="--" , marker="D")

# %%
plt.bar(x,y , color="purple")
# Out:
# <BarContainer object of 4 artists>

# %%
z = np.random.normal(50, 5, 20 )
z
# 50 is the central 5= standard deviation 20= no of elements
# Out:
# array([42.06006392, 44.46207234, 44.3284531 , 49.57538568, 46.51222389,
#        55.3786225 , 54.43568357, 53.05060447, 43.27120212, 55.8531976 ,
#        46.90508283, 51.97323033, 40.10807108, 50.36987763, 51.53805745,
#        50.71047178, 57.89081824, 51.30077097, 45.55634933, 48.7837984 ])

# %%
plt.history(z)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-c969fcbe52e1> in <cell line: 1>()
# ----> 1 plt.history(z)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'history'

# %%
plt.hist(z)
# Out:
# (array([1., 2., 2., 3., 1., 3., 3., 1., 3., 1.]),
#  array([40.10807108, 41.8863458 , 43.66462051, 45.44289523, 47.22116994,
#         48.99944466, 50.77771937, 52.55599409, 54.33426881, 56.11254352,
#         57.89081824]),
#  <BarContainer object of 10 artists>)

# %%
plt.scatter(x,y)

# %%
Class = ['A', 'B','C','D']
A_marks = [100, 59, 60, 40]

# %%
plt.bar(Class, A_marks,color='pink')
plt.xlabel("Class")
plt.ylabel("Marks")
# Out:
# Text(0.5, 0, 'Class')
